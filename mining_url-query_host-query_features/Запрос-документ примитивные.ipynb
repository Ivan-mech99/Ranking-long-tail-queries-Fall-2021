# %%
from tqdm import tqdm
import pandas as pd
import os
import gzip
import zipfile
import shutil
from time import sleep
import pymorphy2
from pyaspeller import YandexSpeller
from lru import LRU
import pickle
from time import sleep
from concurrent.futures import ThreadPoolExecutor
import tarfile
import bz2
import sys
import numpy as np
with open('ill_url_ids.pickle', 'rb') as file:
    ill_url_ids = pickle.load(file)
def transform(arg, ill_url_ids):
    if arg not in ill_url_ids:
        return arg
    else:
        return ill_url_ids[arg]
class URL_info():
    def __init__(self):
        self.total_shows = 0
        self.total_clicks = 0
        self.num_first_clicks = 0
        self.num_last_clicks = 0
        self.show_poses = np.zeros((10,),dtype='int')
        self.show_poses_cl = np.zeros((10,),dtype='int')
        self.click_poses = np.zeros((10,),dtype='int')
        self.time = 0
        self.clicks_on_higher_pos = 0
        self.clicks_on_lower_pos = 0
        self.clicks_after_this = 0
        self.clicks_before_this = 0
        self.is_click_on_higher_pos = 0
        self.is_click_on_lower_pos = 0

# %%
df_marks = pd.read_csv('train.marks.tsv', delimiter='\t', header=None)
df_marks = df_marks.rename(columns={0: "QueryId", 1: "DocumentId"})
df_marks = df_marks.drop(columns=[2])
df_example = pd.read_csv('sample.csv')
all_groups = df_marks.append(df_example)
all_groups = all_groups.reset_index()
all_groups = all_groups.drop(columns=['index'])
all_groups = all_groups.sort_values(by=['QueryId', 'DocumentId']).reset_index()
all_groups = all_groups.drop(columns=['index'])
rev_frame = all_groups.sort_values(by=['DocumentId', 'QueryId']).reset_index()
rev_frame = rev_frame.drop(columns=['index'])

# %%
all_groups
# Out:
#         QueryId  DocumentId
# 0             0        1443
# 1             0        5912
# 2             0        5963
# 3             0        6096
# 4             0        6230
# ...         ...         ...
# 606045     6310      497350
# 606046     6310      512263
# 606047     6310      529857
# 606048     6310      551291
# 606049     6310      561732
#
# [606050 rows x 2 columns]

# %%
q_ids = all_groups['QueryId'].unique()

# %%
q_docs_act = dict()

# %%
for qid in tqdm(q_ids):
    q_docs_act[qid] = set()
    tmp = all_groups[all_groups.QueryId==qid]
    tmp_docs = tmp['DocumentId'].unique()
    for doc in tmp_docs:
        q_docs_act[qid].add(transform(doc, ill_url_ids))
# Out:
# 100%|██████████| 6311/6311 [00:19<00:00, 327.52it/s]

# %%
with open("q_docs_act.pickle", 'wb') as file:
    pickle.dump(q_docs_act, file)

# %%
double_q_dict = dict()

# %%
for key in tqdm(q_docs_act):
    double_q_dict[key] = dict()
    for elem in q_docs_act[key]:
        double_q_dict[key][elem]=URL_info()
# Out:
# 100%|██████████| 6311/6311 [00:08<00:00, 733.38it/s]

# %%
double_q_dict[0]
# Out:
# {340485: <__main__.URL_info at 0x184e6daeaf0>,
#  68106: <__main__.URL_info at 0x184e6daeb80>,
#  203791: <__main__.URL_info at 0x184e6daeb50>,
#  53265: <__main__.URL_info at 0x184e6daec10>,
#  303636: <__main__.URL_info at 0x184e6daeb20>,
#  103960: <__main__.URL_info at 0x184e4a21bb0>,
#  303644: <__main__.URL_info at 0x184e4a21c10>,
#  303652: <__main__.URL_info at 0x184e4a21c40>,
#  107045: <__main__.URL_info at 0x184e4a21c70>,
#  564772: <__main__.URL_info at 0x184e4a21b20>,
#  326702: <__main__.URL_info at 0x184e4a21be0>,
#  326703: <__main__.URL_info at 0x184e4a21b80>,
#  194609: <__main__.URL_info at 0x184e4a21b50>,
#  564788: <__main__.URL_info at 0x184e4a21af0>,
#  113720: <__main__.URL_info at 0x184e4a21ac0>,
#  461893: <__main__.URL_info at 0x184e4a21a90>,
#  461894: <__main__.URL_info at 0x184e4a21a60>,
#  461895: <__main__.URL_info at 0x184e4a21a00>,
#  475209: <__main__.URL_info at 0x184e4a21a30>,
#  30794: <__main__.URL_info at 0x184e4a217c0>,
#  579660: <__main__.URL_info at 0x184e4a21fd0>,
#  579661: <__main__.URL_info at 0x184e4a217f0>,
#  55886: <__main__.URL_info at 0x184e4a218b0>,
#  95313: <__main__.URL_info at 0x184e4a21850>,
#  278100: <__main__.URL_info at 0x184e4a21f10>,
#  278101: <__main__.URL_info at 0x184e4a219a0>,
#  6230: <__main__.URL_info at 0x184e4a218e0>,
#  475221: <__main__.URL_info at 0x184e4a21940>,
#  179293: <__main__.URL_info at 0x184e4a21910>,
#  127588: <__main__.URL_info at 0x184e4a21e20>,
#  303716: <__main__.URL_info at 0x184e4a21970>,
#  6760: <__main__.URL_info at 0x184e4a21880>,
#  564846: <__main__.URL_info at 0x184e4a21790>,
#  564847: <__main__.URL_info at 0x184e4a21760>,
#  22129: <__main__.URL_info at 0x184e4a21730>,
#  303733: <__main__.URL_info at 0x184e4a21700>,
#  98938: <__main__.URL_info at 0x184e4a216a0>,
#  189054: <__main__.URL_info at 0x184e4a216d0>,
#  293506: <__main__.URL_info at 0x184e4a21670>,
#  293507: <__main__.URL_info at 0x184e4a21610>,
#  293508: <__main__.URL_info at 0x184e4a21f70>,
#  293509: <__main__.URL_info at 0x184e4a21640>,
#  22153: <__main__.URL_info at 0x184e4a215e0>,
#  563853: <__main__.URL_info at 0x184e4a21580>,
#  563854: <__main__.URL_info at 0x184e4a21e80>,
#  563855: <__main__.URL_info at 0x184e4a215b0>,
#  563856: <__main__.URL_info at 0x184e4a21550>,
#  22166: <__main__.URL_info at 0x184e4a21520>,
#  52899: <__main__.URL_info at 0x184e4a214f0>,
#  331946: <__main__.URL_info at 0x184e4a214c0>,
#  179885: <__main__.URL_info at 0x184e4a21490>,
#  6830: <__main__.URL_info at 0x184e4a21460>,
#  41647: <__main__.URL_info at 0x184e4a21430>,
#  100527: <__main__.URL_info at 0x184e4a21400>,
#  117938: <__main__.URL_info at 0x184e4a213d0>,
#  95925: <__main__.URL_info at 0x184e4a213a0>,
#  49847: <__main__.URL_info at 0x184e4a21370>,
#  6840: <__main__.URL_info at 0x184e4a21340>,
#  88249: <__main__.URL_info at 0x184e4a21310>,
#  296125: <__main__.URL_info at 0x184e4a212e0>,
#  296126: <__main__.URL_info at 0x184e4a212b0>,
#  278211: <__main__.URL_info at 0x184e4a21280>,
#  293061: <__main__.URL_info at 0x184e4a21250>,
#  22215: <__main__.URL_info at 0x184e4a21220>,
#  78026: <__main__.URL_info at 0x184e4a211f0>,
#  95947: <__main__.URL_info at 0x184e4a21190>,
#  78027: <__main__.URL_info at 0x184e4a211c0>,
#  219340: <__main__.URL_info at 0x184e4a21160>,
#  71890: <__main__.URL_info at 0x184e4a21100>,
#  94419: <__main__.URL_info at 0x184e4a21130>,
#  94420: <__main__.URL_info at 0x184e4a210d0>,
#  94421: <__main__.URL_info at 0x184e4a21070>,
#  101587: <__main__.URL_info at 0x184e4a210a0>,
#  566485: <__main__.URL_info at 0x184e4a21040>,
#  293080: <__main__.URL_info at 0x184e4349130>,
#  566487: <__main__.URL_info at 0x184e4349fd0>,
#  135899: <__main__.URL_info at 0x184e4349fa0>,
#  205024: <__main__.URL_info at 0x184e4349f70>,
#  237280: <__main__.URL_info at 0x184e4349f40>,
#  237281: <__main__.URL_info at 0x184e4349f10>,
#  179942: <__main__.URL_info at 0x184e4349ee0>,
#  293613: <__main__.URL_info at 0x184e4349eb0>,
#  66802: <__main__.URL_info at 0x184e4349e80>,
#  95989: <__main__.URL_info at 0x184e4349e50>,
#  329463: <__main__.URL_info at 0x184e4349df0>,
#  71418: <__main__.URL_info at 0x184e4349d90>,
#  96002: <__main__.URL_info at 0x184e4349d60>,
#  237314: <__main__.URL_info at 0x184e4349d00>,
#  118027: <__main__.URL_info at 0x184e4349ca0>,
#  87311: <__main__.URL_info at 0x184e4349c70>,
#  111887: <__main__.URL_info at 0x184e4349c10>,
#  46868: <__main__.URL_info at 0x184e4349bb0>,
#  5912: <__main__.URL_info at 0x184e4349b80>,
#  293660: <__main__.URL_info at 0x184e4349b50>,
#  312096: <__main__.URL_info at 0x184e4349b20>,
#  312097: <__main__.URL_info at 0x184e4349ac0>,
#  579872: <__main__.URL_info at 0x184e4349af0>,
#  293159: <__main__.URL_info at 0x184e4349a90>,
#  75560: <__main__.URL_info at 0x184e4349a60>,
#  6953: <__main__.URL_info at 0x184e4349a30>,
#  280885: <__main__.URL_info at 0x184e43499d0>,
#  110902: <__main__.URL_info at 0x184e4349a00>,
#  110903: <__main__.URL_info at 0x184e43499a0>,
#  327478: <__main__.URL_info at 0x184e4349970>,
#  95034: <__main__.URL_info at 0x184e4349940>,
#  76091: <__main__.URL_info at 0x184e43498e0>,
#  7486: <__main__.URL_info at 0x184e4349910>,
#  96065: <__main__.URL_info at 0x184e43498b0>,
#  7490: <__main__.URL_info at 0x184e4349880>,
#  111940: <__main__.URL_info at 0x184e4349850>,
#  5963: <__main__.URL_info at 0x184e4349820>,
#  96077: <__main__.URL_info at 0x184e43497f0>,
#  454483: <__main__.URL_info at 0x184e43497c0>,
#  242516: <__main__.URL_info at 0x184e4349790>,
#  340820: <__main__.URL_info at 0x184e4349760>,
#  374614: <__main__.URL_info at 0x184e4349730>,
#  575831: <__main__.URL_info at 0x184e4349700>,
#  242522: <__main__.URL_info at 0x184e43496d0>,
#  62304: <__main__.URL_info at 0x184e43496a0>,
#  90464: <__main__.URL_info at 0x184e4349670>,
#  183141: <__main__.URL_info at 0x184e4349640>,
#  6503: <__main__.URL_info at 0x184e4349610>,
#  515943: <__main__.URL_info at 0x184e43495e0>,
#  515944: <__main__.URL_info at 0x184e43495b0>,
#  183146: <__main__.URL_info at 0x184e4349580>,
#  312682: <__main__.URL_info at 0x184e4349550>,
#  419692: <__main__.URL_info at 0x184e4349520>,
#  564589: <__main__.URL_info at 0x184e43494f0>,
#  88444: <__main__.URL_info at 0x184e43494c0>,
#  102278: <__main__.URL_info at 0x184e4349490>,
#  564616: <__main__.URL_info at 0x184e4349dc0>,
#  56202: <__main__.URL_info at 0x184e4349460>,
#  326541: <__main__.URL_info at 0x184e4349430>,
#  326542: <__main__.URL_info at 0x184e4349400>,
#  103828: <__main__.URL_info at 0x184e43493d0>,
#  87961: <__main__.URL_info at 0x184e4349cd0>,
#  106908: <__main__.URL_info at 0x184e43493a0>,
#  400796: <__main__.URL_info at 0x184e4349370>,
#  1443: <__main__.URL_info at 0x184e4349310>,
#  111013: <__main__.URL_info at 0x184e4349340>,
#  110504: <__main__.URL_info at 0x184e4349be0>,
#  100265: <__main__.URL_info at 0x184e43490d0>,
#  10676: <__main__.URL_info at 0x184e4349100>,
#  92086: <__main__.URL_info at 0x184e43491c0>,
#  229815: <__main__.URL_info at 0x184e4349160>,
#  67513: <__main__.URL_info at 0x184e43492b0>,
#  104377: <__main__.URL_info at 0x184e4349250>,
#  229820: <__main__.URL_info at 0x184e4349e20>,
#  229824: <__main__.URL_info at 0x184e43491f0>,
#  546752: <__main__.URL_info at 0x184e4349220>,
#  102344: <__main__.URL_info at 0x184e4349190>,
#  64459: <__main__.URL_info at 0x184e4349d30>,
#  89035: <__main__.URL_info at 0x184e4349280>,
#  238030: <__main__.URL_info at 0x184e43490a0>,
#  110543: <__main__.URL_info at 0x184e4349040>,
#  15823: <__main__.URL_info at 0x184e4349c40>,
#  6096: <__main__.URL_info at 0x184e4349070>,
#  96215: <__main__.URL_info at 0x184ddec2610>,
#  104407: <__main__.URL_info at 0x184ddec2fd0>,
#  461274: <__main__.URL_info at 0x184ddec2fa0>,
#  563677: <__main__.URL_info at 0x184ddec2f70>,
#  67040: <__main__.URL_info at 0x184ddec2f40>,
#  88547: <__main__.URL_info at 0x184ddec2f10>,
#  439277: <__main__.URL_info at 0x184ddec2ee0>,
#  501230: <__main__.URL_info at 0x184ddec2eb0>,
#  48630: <__main__.URL_info at 0x184ddec2e80>,
#  292855: <__main__.URL_info at 0x184ddec2e50>,
#  578046: <__main__.URL_info at 0x184ddec2e20>}

# %%
exists = set(os.listdir('url_query'))

# %%
for key1 in tqdm(double_q_dict):
    if 'q_{}.pickle'.format(key1) in exists:
        with open('url_query/q_{}.pickle'.format(key1), 'rb') as file:
            obj = pickle.load(file)
            for session in obj:
                #чтсло первых кликов
                if len(session[3])>0:
                    if session[3][0] in q_docs_act[key1]:
                        double_q_dict[key1][session[3][0]].num_first_clicks+=1
                #число последних кликов  
                if len(session[3])>0:
                    if session[3][-1] in q_docs_act[key1]:
                        double_q_dict[key1][session[3][-1]].num_last_clicks+=1
                #число показов
                show_ps = dict()
                for i in range(len(session[2])):
                    show_ps[session[2][i]]=i
                    if session[2][i] in q_docs_act[key1]:
                        double_q_dict[key1][session[2][i]].total_shows+=1
                        #показы на первых 10-ти позициях
                        if i<10:
                            double_q_dict[key1][session[2][i]].show_poses[i]+=1
                #число кликов    
                for i in range(len(session[3])):
                    if session[3][i] in q_docs_act[key1]:
                        double_q_dict[key1][session[3][i]].total_clicks+=1
                        #число кликов после/до клика на этот
                        double_q_dict[key1][session[3][i]].clicks_before_this = i
                        double_q_dict[key1][session[3][i]].clicks_after_this += (len(session[3])-1-i)
                        #клики на первых 10-ти позициях
                        if show_ps[session[3][i]]<10:
                            double_q_dict[key1][session[3][i]].click_poses[show_ps[session[3][i]]]+=1
                #время
                if len(session[4])>1:
                    for i in range(len(session[4])-2):
                        if session[3][i] in q_docs_act[key1]:
                            double_q_dict[key1][session[3][i]].time += ((session[4][i+1]-session[4][i])/1000)
                pos_list = []
                for key in show_ps:
                    pos_list.append(show_ps[key])
                pos_list = np.array(pos_list)
                clicked_set = set()
                for i in range(len(session[3])):
                    if session[3][i] in q_docs_act[key1]:
                        cur_pos = show_ps[session[3][i]]
                        clicked_set.add(session[3][i])
                        a1 = np.sum(pos_list<cur_pos)
                        double_q_dict[key1][session[3][i]].clicks_on_lower_pos+=a1
                        if a1>0:
                            double_q_dict[key1][session[3][i]].is_click_on_lower_pos+=1
                        b1 = np.sum(pos_list>cur_pos)
                        double_q_dict[key1][session[3][i]].clicks_on_higher_pos+=b1
                        if b1>0:
                            double_q_dict[key1][session[3][i]].is_click_on_higher_pos+=1
                for i in range(len(session[3])):
                    if session[3][i] in clicked_set and i<10:
                        double_q_dict[key1][session[3][i]].show_poses_cl[i]+=1
# Out:
# 100%|██████████| 6311/6311 [12:36<00:00,  8.34it/s]

# %%
with open("QDP.pickle", 'wb') as file:
    pickle.dump(double_q_dict, file)

# %%
2+5
# Out:
# 7
